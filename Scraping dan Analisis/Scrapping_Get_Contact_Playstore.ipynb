# %% [markdown]
# #Library

# %%
pip install google-play-scraper

# %%
#Library untuk melakukan Scrapping
from google_play_scraper import app, reviews_all, Sort, reviews
import pandas as pd

# %% [markdown]
# #Scrapping Data Playstore

# %%
# ID aplikasi yang akan di-scrape ulasannya
app_id = 'app.source.getcontact'

# %%
# Mengambil  sebagian ulasan get contact
scrapping = reviews(
    app_id,
    lang='id', # Bahasa Indonesia
    country='id', # Negara Indonesia
    sort=Sort.MOST_RELEVANT,
    count = 15000, # 15 ribu ulasan yang diambil
)

# %%
# Menyimpan ulasan ke file CSV

data = pd.DataFrame(scrapping[0])
data.to_csv('getcontact.csv', index=False)

# %%
df= pd.read_csv("/content/getcontact.csv")
df
# Out:
#                                    reviewId         userName  \
# 0      15faa1ea-c8bd-44bd-af06-05fe25b4e477  Pengguna Google
# 1      7c2cc46c-a1b5-43b7-8736-941e9a6b02f3  Pengguna Google
# 2      0f8a8b07-7e92-4670-a6a0-fa3a393f54b0  Pengguna Google
# 3      4278c999-be46-4634-a6d9-40f2815b6d8d  Pengguna Google
# 4      2569a875-93fe-4afd-8c52-9cf6e142d308  Pengguna Google
# ...                                     ...              ...
# 14995  b241a60a-ba5b-4794-8917-7edbeda3cbae     Agness Intan
# 14996  7a8b26a1-eac9-4d2b-b198-a472cad76afb       Mbak Timur
# 14997  f9b17b4a-1049-4051-8ae3-3646069befab        NATO Nato
# 14998  f4e2cbee-544b-4d26-b43b-c5fff3433b65       suga opizz
# 14999  d2b854f2-fef5-4648-ba19-6d31cb516e52    Amin Nasution
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/EGemoI2N...
# 1      https://play-lh.googleusercontent.com/EGemoI2N...
# 2      https://play-lh.googleusercontent.com/EGemoI2N...
# ...

# %%
df.info() #Cek jumlah data nya
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              15000 non-null  object
#  1   userName              15000 non-null  object
#  2   userImage             15000 non-null  object
#  3   content               15000 non-null  object
#  4   score                 15000 non-null  int64
#  5   thumbsUpCount         15000 non-null  int64
#  6   reviewCreatedVersion  12171 non-null  object
#  7   at                    15000 non-null  object
#  8   replyContent          7618 non-null   object
#  9   repliedAt             7618 non-null   object
#  10  appVersion            12171 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 1.3+ MB
